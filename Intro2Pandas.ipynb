# %% [markdown]
# This is a code from [Intro to Python](https://www.oreilly.com/learning/pythons-pandas-make-data-analysis-easy-and-powerful-with-a-few-lines-of-code) O'Reily article.

# %%
from __future__ import division #so I can have float as std and int as //
import pandas as pd
import pylab
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy
import copy

import pdb #debugger
# %matplotlib inline

# %% [markdown]
# ## import data

# %%
data = pd.read_excel('http://qrc.depaul.edu/Excel_Files/Presidents.xls')
#data.describe()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 15 columns):
# President                 35 non-null object
# Years in office           35 non-null object
# Year first inaugurated    35 non-null int64
# Age at inauguration       35 non-null int64
# State elected from        35 non-null object
# # of electoral votes      35 non-null int64
# # of popular votes        35 non-null object
# National total votes      35 non-null object
# Total electoral votes     35 non-null int64
# Rating points             33 non-null float64
# Political Party           35 non-null object
# Occupation                35 non-null object
# College                   35 non-null object
# % electoral               35 non-null float64
# % popular                 35 non-null object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 4.2+ KB

# %% [markdown]
# #  simple visualisations

# %%
data['Political Party'].value_counts().plot(kind='barh');

# %%
data['Occupation'].value_counts().plot(kind='barh');

# %%
data['College'].value_counts().plot(kind='barh');
